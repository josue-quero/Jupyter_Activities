# %%
# %cd "./drive/MyDrive/TC2008B"

# Adapted by Jorge Cruz from:
# TC2008B. Sistemas Multiagentes y Gráficas Computacionales
# Python server to interact with Unity
# Sergio. Julio 2021


# Size of the board:
width = 30
height = 30
# Out:
# [Errno 2] No such file or directory: './drive/MyDrive/TC2008B'
# /content/drive/MyDrive/TC2008B

# %%
#!pip install pyngrok --quiet

from pyngrok import ngrok
from http.server import BaseHTTPRequestHandler, HTTPServer
import logging
import json
import os

import numpy as np
from boid import Boid

ngrok.install_ngrok()

# Terminate open tunnels if exist
ngrok.kill()

# Open an HTTPs tunnel on port 8585 for http://localhost:8585

port = os.environ.get("PORT", 8585)
server_address = ("", port)

public_url = ngrok.connect(port="8585", proto="http", options={"bind_tls": True})
print("Tracking URL:", public_url)
# Out:
# Tracking URL: NgrokTunnel: "http://5a92-35-236-195-132.ngrok.io" -> "http://localhost:80"

# %%
# Set the number of agents here:
flock = [Boid(*np.random.rand(2)*30, width, height) for _ in range(20)]

def updatePositions():
    global flock
    positions = []
    for boid in flock:
        boid.apply_behaviour(flock)
        boid.update()
        pos = boid.edges()
        positions.append(pos)
    return positions

def positionsToJSON(ps):
    posDICT = []
    for p in ps:
        pos = {
            "x" : p[0],
            "z" : p[1],
            "y" : p[2]
        }
        posDICT.append(pos)
    return json.dumps(posDICT)


class Server(BaseHTTPRequestHandler):
    
    def _set_response(self):
        self.send_response(200)
        self.send_header('Content-type', 'text/html')
        self.end_headers()
        
    def do_GET(self):
        logging.info("GET request,\nPath: %s\nHeaders:\n%s\n", str(self.path), str(self.headers))
        self._set_response()
        self.wfile.write("GET request for {}".format(self.path).encode('utf-8'))

    def do_POST(self):
        content_length = int(self.headers['Content-Length'])
        #post_data = self.rfile.read(content_length)
        post_data = json.loads(self.rfile.read(content_length))
        #logging.info("POST request,\nPath: %s\nHeaders:\n%s\n\nBody:\n%s\n",
                     #str(self.path), str(self.headers), post_data.decode('utf-8'))
        logging.info("POST request,\nPath: %s\nHeaders:\n%s\n\nBody:\n%s\n",
                     str(self.path), str(self.headers), json.dumps(post_data))
        
        '''
        x = post_data['x'] * 2
        y = post_data['y'] * 2
        z = post_data['z'] * 2
        
        position = {
            "x" : x,
            "y" : y,
            "z" : z
        }

        self._set_response()
        #self.wfile.write("POST request for {}".format(self.path).encode('utf-8'))
        self.wfile.write(str(position).encode('utf-8'))
        '''
        
        positions = updatePositions()
        #print(positions)
        self._set_response()
        resp = "{\"data\":" + positionsToJSON(positions) + "}"
        #print(resp)
        self.wfile.write(resp.encode('utf-8'))

def run(server_class=HTTPServer, handler_class=Server, port=8585):
    logging.basicConfig(level=logging.INFO)
    server_address = ('', port)
    httpd = server_class(server_address, handler_class)

    public_url = ngrok.connect(port).public_url
    logging.info("ngrok tunnel \"{}\" -> \"http://127.0.0.1:{}\"".format(public_url, port))

    logging.info("Starting httpd...\n") # HTTPD is HTTP Daemon!
    try:
        httpd.serve_forever()
    except KeyboardInterrupt:   # CTRL+C stops the server
        pass
    httpd.server_close()
    logging.info("Stopping httpd...\n")

#if __name__ == '__main__':
#    from sys import argv
#    
#    if len(argv) == 2:
#        run(port=int(argv[1]))
#    else:
#        run()

# %%
run(HTTPServer, Server)
# Out:
# INFO:pyngrok.ngrok:Opening tunnel named: http-8585-fb387bc2-a548-432c-9556-b8dd326657a8
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="no configuration paths supplied"
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="using configuration at default config path" path=/root/.ngrok2/ngrok.yml
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="open config file" path=/root/.ngrok2/ngrok.yml err=nil
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="client session established" obj=csess id=732176463d6d
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=start pg=/api/tunnels id=57e64b2131be461d
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=end pg=/api/tunnels id=57e64b2131be461d status=200 dur=400.868µs
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=start pg=/api/tunnels id=e419462c9c9acb9a
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=end pg=/api/tunnels id=e419462c9c9acb9a status=200 dur=118.628µs
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=start pg=/api/tunnels id=efee6100a34b66eb
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="started tunnel" obj=tunnels name="http-8585-fb387bc2-a548-432c-9556-b8dd326657a8 (http)" addr=http://localhost:8585 url=http://247f-35-236-195-132.ngrok.io
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg="started tunnel" obj=tunnels name=http-8585-fb387bc2-a548-432c-9556-b8dd326657a8 addr=http://localhost:8585 url=https://247f-35-236-195-132.ngrok.io
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=end pg=/api/tunnels id=efee6100a34b66eb status=201 dur=50.29357ms
# INFO:root:ngrok tunnel "http://247f-35-236-195-132.ngrok.io" -> "http://127.0.0.1:8585"
# INFO:root:Starting httpd...
#
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=start pg="/api/tunnels/http-8585-fb387bc2-a548-432c-9556-b8dd326657a8 (http)" id=0dd92616978706bb
# INFO:pyngrok.process.ngrok:t=2021-08-26T17:51:59+0000 lvl=info msg=end pg="/api/tunnels/http-8585-fb387bc2-a548-432c-9556-b8dd326657a8 (http)" id=0dd92616978706bb status=200 dur=206.19µs
