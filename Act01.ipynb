# %%
# !pip3 install mesa
# !pip3 install numpy
# !pip3 install matplotlib

# %%
# La clase `Model` se hace cargo de los atributos a nivel del modelo, maneja los agentes. 
# Cada modelo puede contener múltiples agentes y todos ellos son instancias de la clase `Agent`.
from mesa import Agent, Model 

# Debido a que es posible tener multiples agentes una sola celda elegimos `MultipleGrid`.
from mesa.space import MultiGrid

# Con `SimultaneousActivation` hacemos que todos los agentes se activen de manera simultanea.
from mesa.time import SimultaneousActivation

# Vamos a hacer uso de `DataCollector` para obtener el grid completo cada paso (o generación) y lo usaremos para graficarlo.
from mesa.datacollection import DataCollector

# mathplotlib lo usamos para graficar/visualizar como evoluciona el autómata celular.
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams["animation.html"] = "jshtml"
matplotlib.rcParams['animation.embed_limit'] = 2**128

# Definimos los siguientes paquetes para manejar valores númericos.
import numpy as np
import pandas as pd

# Definimos otros paquetes que vamos a usar para medir el tiempo de ejecución de nuestro algoritmo.
import time
import datetime
import math

# %%
def get_grid(model):
    '''
    Esta es una función auxiliar que nos permite guardar el grid para cada uno de los agentes.
    param model: El modelo del cual optener el grid.
    return una matriz con la información del grid del agente.
    '''
    grid = np.zeros((model.grid.width, model.grid.height))
    for cell in model.grid.coord_iter():
        cell_content, x, y = cell
        for content in cell_content:
            if isinstance(content, Cleaner):
                grid[x][y] = 2
            elif grid[x][y] == 0:
                grid[x][y] = content.dirty
    return grid

class RandomWalker(Agent):
    """
    Class implementing random walker methods in a generalized manner.
    Not indended to be used on its own, but to inherit its methods to multiple
    other agents.
    """

    grid = None
    x = None
    y = None

    def __init__(self, unique_id, pos, model):
        """
        grid: The MultiGrid object in which the agent lives.
        x: The agent's current x coordinate
        y: The agent's current y coordinate
        """
        super().__init__(unique_id, model)
        self.pos = pos

    def random_move(self):
        """
        Step one cell in any allowable direction.
        """
        # Pick the next cell from the adjacent cells.
        next_moves = self.model.grid.get_neighborhood(self.pos, True, False)
        next_move = self.random.choice(next_moves)
        # Now move:
        self.model.grid.move_agent(self, next_move)

class Cleaner(RandomWalker):
    """
    A cleaner that walks around and cleanes the floor if it detects that is dirty.
    The init is the same as the RandomWalker.
    """
    def __init__(self, unique_id, pos, model):
        super().__init__(unique_id, pos, model)

    def step(self):
        """
        A model step. Move, then eat grass and reproduce.
        """
        moving = True
        this_cell = self.model.grid.get_cell_list_contents([self.pos])
        for content in this_cell:
            print(content)
            if isinstance(content, Floor):
                print("Floor")
                if content.dirty:
                    content.dirty = 0
                    moving = False
        if moving:
            self.random_move()
            

class Floor(Agent):
    """
    A floor tile that it is cleaned by the Cleaner
    """

    def __init__(self, unique_id, pos, model, dirty):
        """
        Creates a floor tile
        Args:
            dirty: (boolean) Whether the floor tile is dirty or not
        """
        super().__init__(unique_id, model)
        self.dirty = dirty
        self.pos = pos
                
            
class GameLifeModel(Model):
    '''
    Define el modelo de la actividad.
    '''
    def __init__(self, width, height, initial_dirty_tiles, initial_cleaners):
        super().__init__()
        self.height = height
        self.width = width
        self.initial_cleaners = initial_cleaners
        self.initial_dirty_tiles = initial_dirty_tiles
        self.grid = MultiGrid(self.width, self.height, True)
        self.schedule = SimultaneousActivation(self)
        
        # Aquí definimos con colector para obtener el grid completo.
        self.datacollector = DataCollector(
            model_reporters={"Grid": get_grid})
        
        # Create cleaners:
        for i in range(self.initial_cleaners):
            x = 1
            y = 1
            cleaner = Cleaner(self.next_id(), (x, y), self)
            self.grid.place_agent(cleaner, (x, y))
            self.schedule.add(cleaner)
            
        # Create dirty and clean tiles
        counter_dirty_tiles = 0
        for agent, x, y in self.grid.coord_iter():
            if counter_dirty_tiles >= self.initial_dirty_tiles:
                return
            dirty = self.random.choice([0, 1])
            if dirty:
                counter_dirty_tiles += 1

            floor_tile = Floor(self.next_id(), (x, y), self, dirty)
            self.grid.place_agent(floor_tile, (x, y))
            self.schedule.add(floor_tile)
        
    
    def step(self):
        '''
        En cada paso el colector tomará la información que se definió y almacenará el grid para luego graficarlo.
        '''
        self.datacollector.collect(self)
        self.schedule.step()

# %%
# Definimos el tamaño del Grid
height_m = 10
width_n = 10

# Definimos el número de generaciones a correr
PORCENTAGE_DIRTY_TILES = 50
AMOUNT_DIRTY_TILES = math.floor((height_m * width_n) * (PORCENTAGE_DIRTY_TILES/100))
MAX_TIME = 0.5
NUM_CLEANERS = 3

# Registramos el tiempo de inicio y corremos el modelo
start_time = time.time()
limit_time = datetime.timedelta(seconds=MAX_TIME)
model = GameLifeModel(height_m, width_n, AMOUNT_DIRTY_TILES, NUM_CLEANERS)
while datetime.timedelta(seconds=(time.time() - start_time)) < limit_time:
    model.step()

# Imprimimos el tiempo que le tomó correr al modelo.
print('Tiempo de ejecución:', str(datetime.timedelta(seconds=(time.time() - start_time))))
# Out:
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159ad0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Floor object at 0x7f6830159d50>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159ad0>
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Floor object at 0x7f6830159d50>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159b10>, <__main__.Floor object at 0x7f6830159d50>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f68304ac710>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68304ac710>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b210>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f683013b210>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b210>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f683013b210>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f68303c83d0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f68303c83d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f68303c83d0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f68303c83d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f68303c83d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f68303c83d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159dd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159dd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159dd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159dd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d10>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d10>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b1d0>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f683013b1d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b210>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013b210>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f68304ac710>, <__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68304ac710>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f68304ac710>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68304ac710>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b190>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f683013b190>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159d10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b190>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f683013b190>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159cd0>, <__main__.Cleaner object at 0x7f6830159b10>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159cd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159cd0>, <__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Floor object at 0x7f6830159cd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159f10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f050>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f050>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159f50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f050>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f050>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159f50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f210>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f210>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f210>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f210>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f210>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f210>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f490>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f490>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f450>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f450>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f050>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f050>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f1d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f1d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159ed0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159ed0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159e90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159e90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f510>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f510>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159e90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159e90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f510>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f510>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f190>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f190>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f4d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f4d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f190>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f190>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f4d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f4d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f410>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f410>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f510>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f510>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f410>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f410>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f290>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f290>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f650>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f650>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f650>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f650>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f710>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f710>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f690>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f690>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f710>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f710>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f690>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f690>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f950>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f950>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f3d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f3d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f950>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f950>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f3d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f3d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f6d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f6d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f690>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f690>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f950>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f950>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f650>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f650>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f990>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f990>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f610>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f610>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f990>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f990>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f390>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f390>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f0d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f0d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f950>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f950>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f310>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f310>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f6d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f6d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f310>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f310>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f910>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f910>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f0d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f0d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f350>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f350>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe90>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f350>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f350>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f110>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f110>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f110>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f110>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f3d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f3d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f110>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f110>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159e90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159e90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159ed0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159ed0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f10>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f10>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f9d0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f9d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f210>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f210>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f990>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013f990>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f490>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f490>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f210>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f210>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe90>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159f90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159f90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fc10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fc10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f290>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f290>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f510>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f510>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f250>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f250>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fbd0>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fbd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f2d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f2d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe10>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe10>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f090>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f090>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013fe50>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013fe50>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# Cell total content:
# [<__main__.Floor object at 0x7f683013f090>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013f090>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b110>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Floor object at 0x7f683013b110>
# Floor
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d90>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d90>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159fd0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159fd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d10>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d10>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f68309795d0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68309795d0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f683013b190>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f683013b190>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f68304ac710>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f68304ac710>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159d50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159d50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159b50>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159b50>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Floor object at 0x7f6830159dd0>, <__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Floor object at 0x7f6830159dd0>
# Floor
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# ...
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159ad0>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159ad0>
# Cell total content:
# [<__main__.Cleaner object at 0x7f6830159a90>, <__main__.Cleaner object at 0x7f6830159b10>]
# Each content:
# <__main__.Cleaner object at 0x7f6830159a90>
# <__main__.Cleaner object at 0x7f6830159b10>
# Tiempo de ejecución: 0:00:00.501191

# %%
all_grid = model.datacollector.get_model_vars_dataframe()

# %%
# %%capture

fig, axs = plt.subplots(figsize=(7,7))
axs.set_xticks([])
axs.set_yticks([])
patch = plt.imshow(all_grid.iloc[0][0], cmap='Greys')

def animate(i):
    patch.set_data(all_grid.iloc[i][0])
    
anim = animation.FuncAnimation(fig, animate, frames=len(all_grid))

# %%
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9bdfdf6a8b214859bde507b09c3e1eae">
#   <div class="anim-controls">
#     <input id="_anim_slider9bdfdf6a8b214859bde507b09c3e1eae" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9bdfdf6a8b214859bde507b09c3e1eae.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9bdfdf6a8b214859bde507b09c3e1eae.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9bdfdf6a8b214859bde507b09c3e1eae"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9bdfdf6a8b214859bde507b09c3e1eae"
#              >
#       <label for="_anim_radio1_9bdfdf6a8b214859bde507b09c3e1eae">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9bdfdf6a8b214859bde507b09c3e1eae"
#              checked>
#       <label for="_anim_radio2_9bdfdf6a8b214859bde507b09c3e1eae">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9bdfdf6a8b214859bde507b09c3e1eae"
#              >
#       <label for="_anim_radio3_9bdfdf6a8b214859bde507b09c3e1eae">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9bdfdf6a8b214859bde507b09c3e1eae";
#     var slider_id = "_anim_slider9bdfdf6a8b214859bde507b09c3e1eae";
#     var loop_select_id = "_anim_loop_select9bdfdf6a8b214859bde507b09c3e1eae";
#     var frames = new Array(249);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwY

# %%
#all_grid = model.datacollector.get_model_vars_dataframe()
#print (all_grid.tail()['Movimientos'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Movimientos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5803139e3273> in <module>
#       1 all_grid = model.datacollector.get_model_vars_dataframe()
# ----> 2 print (all_grid.tail()['Movimientos'].sum())
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Movimientos'
